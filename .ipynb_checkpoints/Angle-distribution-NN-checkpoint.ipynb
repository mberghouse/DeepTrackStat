# %%
import pandas as pd
import numpy as np
import cv2
import os
import torch
import re
#torch.set_default_dtype(torch.float16)
k=40


# train_image_files=['../500part_4xspeed_heterogeneous/','../2000part_4xspeed_heterogeneous/', '../2000part_16xspeed_heterogeneous/',
#                   '../2000part_32xspeed_heterogeneous/','../1000part_16xspeed_heterogeneous/','../500part_32xspeed_heterogeneous/',
#                   '../1000part_32xspeed_heterogeneous/', 'sim2/', 'sim11/', 'sim12/', 'sim13/', 'sim14/', 'sim19/','sim20/','sim21/',
#                    'sim22/','sim23/','sim24/','sim25/','sim35/','sim36/','sim46/','sim62/','sim63/','sim64/','sim65/','sim66/',
#                   'sim67/','sim16/']
train_image_files=['sim62/','sim63/','sim64/','sim66/',
                  'sim67/','sim68/','sim69/', 'sim72/','sim73/','sim74/','sim76/',
                  'sim77/','sim78/','sim79/', 'sim82/','sim83/','sim84/','sim86/',
                  'sim87/','sim88/','sim89/']
test_image_files=['sim61/','sim65/','sim70/','sim71/','sim75/','sim80/','sim81/','sim85/','sim90/']
images_train = torch.zeros(len(train_image_files),k,1000, 1000)
images_test = torch.zeros(len(test_image_files),k,1000, 1000)
for i in range(len(train_image_files)):
    base = train_image_files[i]
    im_dir = os.listdir(base)
    im_dir = sorted(im_dir, key=lambda x: int(re.findall(r'\d+', x)[0]))
    for j in range(k):
        images_train[i,j,:,:] = torch.tensor(cv2.resize(cv2.imread(base+im_dir[j], cv2.IMREAD_GRAYSCALE),(1000,1000)))


for i in range(len(test_image_files)):
    base = test_image_files[i]
    im_dir = os.listdir(base)
    im_dir = sorted(im_dir, key=lambda x: int(re.findall(r'\d+', x)[0]))
    for j in range(k):
        images_test[i,j,:,:] = torch.tensor(cv2.resize(cv2.imread(base+im_dir[j], cv2.IMREAD_GRAYSCALE),(1000,1000)))
        
im_dir
# Out:
# ['Fig_1.jpg',
#  'Fig_2.jpg',
#  'Fig_3.jpg',
#  'Fig_4.jpg',
#  'Fig_5.jpg',
#  'Fig_6.jpg',
#  'Fig_7.jpg',
#  'Fig_8.jpg',
#  'Fig_9.jpg',
#  'Fig_10.jpg',
#  'Fig_11.jpg',
#  'Fig_12.jpg',
#  'Fig_13.jpg',
#  'Fig_14.jpg',
#  'Fig_15.jpg',
#  'Fig_16.jpg',
#  'Fig_17.jpg',
#  'Fig_18.jpg',
#  'Fig_19.jpg',
#  'Fig_20.jpg',
#  'Fig_21.jpg',
#  'Fig_22.jpg',
#  'Fig_23.jpg',
#  'Fig_24.jpg',
#  'Fig_25.jpg',
#  'Fig_26.jpg',
#  'Fig_27.jpg',
#  'Fig_28.jpg',
#  'Fig_29.jpg',
#  'Fig_30.jpg',
#  'Fig_31.jpg',
#  'Fig_32.jpg',
#  'Fig_33.jpg',
#  'Fig_34.jpg',
#  'Fig_35.jpg',
#  'Fig_36.jpg',
#  'Fig_37.jpg',
#  'Fig_38.jpg',
#  'Fig_39.jpg',
#  'Fig_40.jpg']

# %%
import matplotlib.pyplot as plt
plt.imshow(images_train[0,0,:,:])

# %%
import matplotlib.pyplot as plt
from scipy.stats import exponweib,lognorm, johnsonsb,expon
import torch
import numpy as np

def calculate_angles(x_arr, y_arr):
    traj_stats=[]
    for n in range(x_arr.shape[0]):
        x_diff = np.diff(x_arr[:,n])
        y_diff = np.diff(y_arr[:,n])
        angles=np.zeros((len(x_diff),1))
        for i in range(len(x_diff)-1):
            theta_1=np.arctan(y_diff[i]/x_diff[i])
            theta_2=np.arctan(y_diff[i+1]/x_diff[i+1])
            angles[i]=(theta_2-theta_1)*(180/np.pi)
    
        traj_stats.append([n, angles])
    angle_array=[]
    vel_array=[]
    for i in range(len(traj_stats)):
        section1=traj_stats[i][1]
        section1=np.reshape(section1,(len(section1),))
        angle_array=np.hstack([section1,angle_array])
    
    angle_array
    angle_array=np.abs(angle_array[~np.isnan(angle_array)])
    angle_array = interpolate_vectors(np.sort(angle_array), target_length)
    angle_array[angle_array==0]=0.1
    return angle_array
    
def interpolate_vectors(vector, target_length):
    current_length = len(vector)
    # Create a new x-axis with the desired length
    new_x = np.linspace(0, current_length - 1, target_length)
    # Create the old x-axis based on the current length
    old_x = np.arange(current_length)
    # Perform linear interpolation
    interpolated_vector = np.interp(new_x, old_x, vector)
    return interpolated_vector
    
#k=100
# train_dirs=[["xc_500part_4xspeed.csv","yc_500part_4xspeed.csv"],["xc_2000part_4xspeed.csv","yc_2000part_4xspeed.csv"],
#             ["xc_2000part_16xspeed.csv","yc_2000part_16xspeed.csv"],["xc_2000part_32xspeed.csv","yc_2000part_32xspeed.csv"],
#            ["xc_1000part_16xspeed.csv","yc_1000part_16xspeed.csv"],["xc_500part_32xspeed.csv","yc_500part_32xspeed.csv"],
#            ["xc_1000part_32xspeed.csv","yc_1000part_32xspeed.csv"], ['yc_sim2.csv','xc_sim2.csv'], ['yc_sim11.csv','xc_sim11.csv'],
#             ['yc_sim12.csv','xc_sim12.csv'],['yc_sim13.csv','xc_sim13.csv'],['yc_sim14.csv','xc_sim14.csv'],['yc_sim15.csv','xc_sim15.csv'],
#             ['yc_sim19.csv','xc_sim19.csv'],['yc_sim20.csv','xc_sim20.csv'],['yc_sim21.csv','xc_sim21.csv'],['yc_sim22.csv','xc_sim22.csv'],
#             ['yc_sim23.csv','xc_sim23.csv'],['yc_sim24.csv','xc_sim24.csv'],['yc_sim25.csv','xc_sim25.csv'],
#             ['yc_sim35.csv','xc_sim35.csv'],['yc_sim36.csv','xc_sim36.csv'],['yc_sim46.csv','xc_sim46.csv'],['yc_sim62.csv','xc_sim62.csv'],
#             ['yc_sim63.csv','xc_sim63.csv'],['yc_sim64.csv','xc_sim64.csv'],['yc_sim65.csv','xc_sim65.csv'],['yc_sim66.csv','xc_sim66.csv'],
#             ['yc_sim67.csv','xc_sim67.csv'],
#             ['yc_sim16.csv','xc_sim16.csv']]
train_dirs=[['yc_sim62.csv','xc_sim62.csv'],['yc_sim63.csv','xc_sim63.csv'],['yc_sim64.csv','xc_sim64.csv'],['yc_sim66.csv','xc_sim66.csv'],
            ['yc_sim67.csv','xc_sim67.csv'],['yc_sim68.csv','xc_sim68.csv'],['yc_sim69.csv','xc_sim69.csv'],
            ['yc_sim72.csv','xc_sim72.csv'],['yc_sim73.csv','xc_sim73.csv'],['yc_sim74.csv','xc_sim74.csv'],['yc_sim76.csv','xc_sim76.csv'],
            ['yc_sim77.csv','xc_sim77.csv'],['yc_sim78.csv','xc_sim78.csv'],['yc_sim79.csv','xc_sim79.csv'],
            ['yc_sim82.csv','xc_sim82.csv'],['yc_sim83.csv','xc_sim83.csv'],['yc_sim84.csv','xc_sim84.csv'],['yc_sim86.csv','xc_sim86.csv'],
            ['yc_sim87.csv','xc_sim87.csv'],['yc_sim88.csv','xc_sim88.csv'],['yc_sim89.csv','xc_sim89.csv'],
]

train_dirs[0]

# xtorch = torch.zeros(len(train_dirs),1000)
# distr_torch = torch.zeros(len(train_dirs),1000)
scales = torch.zeros(len(train_dirs),2)
# i=0
target_length=1000
angles = torch.zeros(len(train_dirs),target_length)
for i in range(len(train_dirs)):
    x_arr= np.array(pd.read_csv(train_dirs[i][1], header=None))
    y_arr= np.array(pd.read_csv(train_dirs[i][0], header=None))
    angle_array = calculate_angles(x_arr,y_arr)

    angles[i,:] = torch.tensor(angle_array)
    
    a,b = expon.fit(angle_array)
    
    # Generate points for plotting the fitted distribution
    xtorch= np.linspace(expon.ppf(0.01, a,b),
                    expon.ppf(0.99, a,b), target_length)
    
    distr_torch=expon.pdf(xtorch, a,b)
    scales[i,:] = torch.tensor([a,b])
    plt.plot(xtorch,distr_torch)
    plt.show()
    
    

# images_train = images_train/255
# images_test = images_test/255
#torch.max(scales,dim=0)[0]

# %%
import numpy as np
from scipy import stats
from joblib import Parallel, delayed
import matplotlib.pyplot as plt
angle_array[angle_array==0]=0.1

def fit_distribution(data, dist):
    params = dist.fit(data)
    nll = (-np.sum(dist.logpdf(data, *params)))/len(data)
    return dist, params, nll

def find_best_distribution(data):
    distributions = [
        stats.genexpon, stats.genpareto, stats.johnsonsb, stats.invweibull,
        stats.expon, stats.maxwell, stats.johnsonsu, stats.norminvgauss,
        stats.gompertz, stats.wald, stats.powerlognorm, stats.vonmises
    ]
    
    results = Parallel(n_jobs=12)(delayed(fit_distribution)(data, dist) for dist in distributions)
    return results


# Example usage

results = find_best_distribution(angle_array)

# %%
fig, axs = plt.subplots(4, 3, figsize=(15, 15))
axs = axs.ravel()

for i, (dist, params, sse) in enumerate(results):
    x = np.linspace(angle_array.min(), angle_array.max(), 100)
    axs[i].hist(angle_array, bins=100, density=True, alpha=0.6, color='blue')
    axs[i].plot(x, dist.pdf(x, *params), 'r-', lw=2, label=f'Fit: {dist.name}')
    axs[i].legend(loc='best')
    axs[i].set_title(f'{dist.name} (NLL = {sse:.4f})')
    axs[i].set_xlabel('Data')
    axs[i].set_ylabel('Probability Density')

plt.tight_layout()
plt.show()

# %%
from joblib.externals.loky import get_reusable_executor
get_reusable_executor().shutdown(wait=True)

# %%
# xtorch_test = torch.zeros(len(test_dirs),1000)
# distr_torch_test = torch.zeros(len(test_dirs),1000)

# test_dirs=[["xc_1000part_4xspeed.csv","yc_1000part_4xspeed.csv"],["xc_500part_16xspeed.csv","yc_500part_16xspeed.csv"],
#           ['yc_sim17.csv','xc_sim17.csv'],['yc_sim18.csv','xc_sim18.csv'], ['yc_sim40.csv','xc_sim40.csv'], ['yc_sim41.csv','xc_sim41.csv'], 
#            ['yc_sim42.csv','xc_sim42.csv'], ['yc_sim43.csv','xc_sim43.csv'], ['yc_sim44.csv','xc_sim44.csv'], ['yc_sim45.csv','xc_sim45.csv'],
#            ['yc_sim69.csv','xc_sim69.csv'],['yc_sim70.csv','xc_sim70.csv'],
# ]
test_dirs=[ ['yc_sim61.csv','xc_sim61.csv'], ['yc_sim65.csv','xc_sim65.csv'],['yc_sim70.csv','xc_sim70.csv'],
           ['yc_sim71.csv','xc_sim71.csv'], ['yc_sim75.csv','xc_sim75.csv'],['yc_sim80.csv','xc_sim80.csv'],
           ['yc_sim81.csv','xc_sim81.csv'], ['yc_sim85.csv','xc_sim85.csv'],['yc_sim90.csv','xc_sim90.csv'],
]
scales_test = torch.zeros(len(test_dirs),2)
# target_length=1000
angles_test = torch.zeros(len(test_dirs),target_length)
for i in range(len(test_dirs)):
    x_arr= np.array(pd.read_csv(test_dirs[i][1], header=None))
    y_arr= np.array(pd.read_csv(test_dirs[i][0], header=None))
    angle_array = calculate_angles(x_arr,y_arr)

    angles_test[i,:] = torch.tensor(angle_array)
    
    a,b = expon.fit(angle_array)
    
    # Generate points for plotting the fitted distribution
    xtorch= np.linspace(expon.ppf(0.01, a,b),
                    expon.ppf(0.99, a,b), target_length)
    
    distr_torch=expon.pdf(xtorch, a,b)
    scales_test[i,:] = torch.tensor([a,b])
    plt.plot(xtorch,distr_torch)
    plt.show()
# torch.max(scales_test,dim=0)

# %%
from torch import nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        l=200
        self.fc2=nn.Conv2d(100, l, 1, stride=2)
        #self.m1 = nn.BatchNorm1d(1000)
        self.d1 = nn.Dropout(.2)
        self.fc1=nn.Conv2d(40, 100, 1, stride=2)
        #self.m2 = nn.BatchNorm1d(l)
        self.d2 = nn.Dropout(.2)
       # self.fc2 = nn.Linear(800,l)
       # self.fc3=nn.Linear(2000,800)
       # self.fc4 = nn.Linear(800,l)
        self.fc5 = nn.Conv2d(l, 5,1, stride=1)
        #self.m3 = nn.BatchNorm1d(100)
        self.fc6 = nn.Linear(312500,1000)
        self.d3 = nn.Dropout(.2)
        self.fc7 = nn.Linear(100,4)
        self.fc8 = nn.Linear(2000,1000)

    def forward(self, x):
        b = x.shape[0]
        x = x.squeeze()
        
        l=200
        x = F.relu(self.fc1(x))
        #x = self.m1(x)
        x = self.d1(x)
        x = F.relu(self.fc2(x))
        #x = self.m2(x)
        x = self.d2(x)
        #x = x.permute(0,2,1)
        #x = F.relu(self.fc3(x))
        #x = F.relu(self.fc4(x))
        
        #x = x.view(b,l*666)
        x = F.relu(self.fc5(x))
        #x = self.m3(x)
        x = x.reshape(b, -1)
        #x = F.relu(self.fc4(x))
        x = (self.fc6(x))
        # x = self.d3(x)
        # #x = torch.flatten(x)
        # x = (self.fc8(x))
        # x = x.reshape(2,200)
        #x = self.fc7(x)
        #output = nn.functional.log_softmax(x, dim=1)
        return x
    
    
class Net2(nn.Module):
    def __init__(self):
        super(Net2, self).__init__()
        self.m1 = timm.create_model('regnetx_016', in_chans=40, drop_path_rate=.0,num_classes=4000,pretrained=True)

        self.fc1=nn.Linear(4000,1000)
        self.fc2 = nn.Linear(1000,1000)

        self.fc3=nn.Linear(4000,10)
        self.fc3_2=nn.Linear(10,1)
        self.fc4=nn.Linear(4000,10)
        self.fc4_2=nn.Linear(10,1)
        self.fc5=nn.Linear(4000,10)
        self.fc5_2=nn.Linear(10,1)

    def forward(self, x):
        x = self.m1(x)
        
        x1 = F.gelu(self.fc1(x))
        x1 = self.fc2(x1)

        x2 = F.gelu(self.fc3(x))
        x2 = self.fc3_2(x2)
        x3 = F.gelu(self.fc4(x))
        x3 = self.fc4_2(x3)


        return x1,x2,x3
    
class Net3(nn.Module):
    def __init__(self):
        super(Net3, self).__init__()
        l=80

        self.fc1=nn.Linear(1000,l)
        self.d1 = nn.Dropout(.1)
        self.fc2=nn.Linear(1000,l)
        self.d2 = nn.Dropout(.1)
        self.fc3 = nn.Linear(40*l*l,1000)
        self.d3 = nn.Dropout(.1)
        self.fc4 = nn.Linear(1000,250)
        self.fc4_2 = nn.Linear(250,1000)
#         self.fc4_3 = nn.Linear(800,300)
#         self.fc5 = nn.Linear(300,30)
# #         self.fc5_2 = nn.Linear(200,100)
# #         self.fc5_3 = nn.Linear(100,30)
#         self.fc6 = nn.Linear(30,3)

    def forward(self, x):
        b = x.shape[0]
        x = F.relu(self.fc1(x))
        x = self.d1(x)
        x = x.permute(0,1,3,2)
        x = F.relu(self.fc2(x))
        x = self.d2(x)
        x = torch.reshape(x, [b,-1])
        x = F.relu(self.fc3(x))
        x = self.d3(x)
        x = F.relu(self.fc4(x))
        #x = torch.reshape(x, [b,10000])
        x = (self.fc4_2(x))
#         x = F.rrelu(self.fc4_3(x))
#         x = F.rrelu(self.fc5(x))
# #         x = F.rrelu(self.fc5_2(x))
# #         x = F.rrelu(self.fc5_3(x))
#         x = self.fc6(x)
        #x = torch.reshape(x, [b,2,100])
        #x = self.fc7(x)
        #output = nn.functional.log_softmax(x, dim=1)
        return x

# %%
images_train = images_train/255
images_test = images_test/255

# %%
# from ultralytics import YOLO

# # Load the pretrained YOLO model
# model = YOLO('yolov8n.pt')  # You can choose a different model variant if desired

# import torch
# import torch.nn as nn
# model.model.model[0].conv = nn.Conv2d(40, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
# model.model.model[-1].dfl = nn.Conv2d(16, 1000, kernel_size=(1, 1), stride=(1, 1), bias=False)
# model

# %%
torch.cuda.empty_cache()
gc.collect()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 torch.cuda.empty_cache()
# ----> 2 gc.collect()
#
# NameError: name 'gc' is not defined

# %%
angles_test
# Out:
# tensor([[1.0000e-01, 1.0000e-01, 1.0000e-01,  ..., 1.7343e+02, 1.7535e+02,
#          1.7671e+02],
#         [1.0000e-01, 1.0000e-01, 1.0000e-01,  ..., 1.7391e+02, 1.7717e+02,
#          1.7832e+02],
#         [1.0000e-01, 1.0000e-01, 1.0000e-01,  ..., 1.7327e+02, 1.7372e+02,
#          1.7910e+02],
#         ...,
#         [1.0000e-01, 1.0000e-01, 1.0000e-01,  ..., 1.7129e+02, 1.7369e+02,
#          1.7811e+02],
#         [1.0000e-01, 1.0000e-01, 1.0000e-01,  ..., 1.7242e+02, 1.7445e+02,
#          1.7650e+02],
#         [1.0000e-01, 1.0000e-01, 1.0000e-01,  ..., 1.7351e+02, 1.7582e+02,
#          1.7897e+02]])

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import gc
from torch.optim.lr_scheduler import StepLR
import torchvision as tv
import timm
device='cuda'
# m1 = timm.create_model('regnety_016', in_chans=40, drop_path_rate=.0,num_classes=4000,pretrained=True)
model=Net2()
model.to(device)
# Define your custom dataset
class TestDataset(Dataset):
    def __init__(self, images, x, scales):#x,y,scales):
        self.images = images
        self.x = x
        # self.y = y
        self.scales = scales

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        image = self.images[index,:,:,:]
        #image  = tv.transforms.Resize(size=1000)(image)
        #image  = torch.tensor(image)
        x = self.x[index,:]
        # y = torch.tensor(self.y[index,:])
        scales1 = self.scales[index,0]
        scales2 = self.scales[index,1]
       # scales3 = self.scales[index,2]
        return image.float(), x.float(),scales1.float(),scales2.float()#,y.float(),  scales.float()
import random
class TrainDataset(Dataset):
    def __init__(self, images, x, scales):#x,y,scales):
        self.images = images
        self.x = x
        # self.y = y
        self.scales = scales

    def __len__(self):
        return len(self.images)

    def __getitem__(self, index):
        image = self.images[index,:,:,:]
        #image  = tv.transforms.Resize(size=1000)(image)
        # if random.random() < 0.5:
        #     scale_factor = random.uniform(.95, 1.05)
        #     image *= scale_factor
        if random.random() < 0.5:
            image = image.flip(dims=[-1]) 
        if random.random() < 0.5:
            image = image.flip(dims=[-2])  # Assuming W=50 is the middle axis for flipping

    # # Flip across the horizontal axis (H dimension) for input and label with a 50% chance
        if random.random() < 0.5:
            # # For input, assuming H=200 is the middle
            image = image.flip(dims=[-3])  # Flipping the last dimension (H)
            # # For label, assuming H=1000 is the middle
        

        x = self.x[index,:]
        # y = torch.tensor(self.y[index,:])
        scales1 = self.scales[index,0]
        scales2 = self.scales[index,1]
        #scales3 = self.scales[index,2]
        return image.float(), x.float(),scales1.float(),scales2.float()#,y.float(),  scales.float()


# Define your model architecture

import torch
from torch.utils.data import DataLoader, Sampler
import numpy as np



# Assuming you have your grayscale images and labels loaded in memory
from torch.optim.lr_scheduler import ExponentialLR
# Create an instance of the custom dataset
# x = torch.nan_to_num(xc_data).unsqueeze(dim=2)
# y = torch.nan_to_num(yc_data).unsqueeze(dim=2)
# x_test = torch.nan_to_num(xc_data3).unsqueeze(dim=2)
# y_test = torch.nan_to_num(yc_data3).unsqueeze(dim=2)
# coords = torch.cat((x,y), dim=2)
# coords_test = torch.cat((x_test,y_test), dim=2)
#images = images[0:14,:,:]
# from sklearn.preprocessing import StandardScaler
# scalerx = StandardScaler()
# scalery = StandardScaler()
# # xtorch=scalerx.fit_transform(xtorch)
# # distr_torch=scalery.fit_transform(distr_torch)
# maxs = torch.max(scales)
# # mins = torch.min(scales)
# # print(maxs,mins)
# scales2 = (scales)/(maxs)
# # scales2 = (scales-mins)/(maxs-mins)

#maxs = torch.max(speeds)
#mins = torch.min(speeds)
#print(maxs,mins)
## scales_test2 = (scales_test)/(maxs)
#speeds2 = (speeds-mins)/(maxs-mins)

#maxs = torch.max(speeds_test)
#mins = torch.min(speeds_test)
#print(maxs,mins)
## scales_test2 = (scales_test)/(maxs)
#speeds_test2 = (speeds_test-mins)/(maxs-mins)
## xtorch_test=scalerx.transform(xtorch_test)
## distr_torch_test=scalery.transform(distr_torch_test)
dataset = TrainDataset(images_train, angles, scales)#xtorch, distr_torch,scales2)


# Create a dataloader
batch_size = 11
torch.cuda.empty_cache()
gc.collect()
#dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=False, drop_last=True)
# Create the GroupedSampler with a group size of 4
#sampler = GroupedSampler(dataset, group_size=batch_size)
#images3 = images3.unsqueeze(dim=0)
# Create the DataLoader with the GroupedSampler
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True,drop_last=False,num_workers=0)#,sampler=sampler)
dataset_test = TestDataset(images_test,angles_test, scales_test)#  xtorch_test, distr_torch_test, scales_test2)
batch_size = 5
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=False, drop_last=False, num_workers=0)
#model = Net().to(device)
#model2 = Net2().to(device)
# Define the loss function and optimizer
criterion = nn.MSELoss()
optimizer = optim.AdamW(model.parameters(),lr=0.0004,weight_decay=.2)
#optimizer2 = optim.Adam(model2.parameters(), lr=0.00001)
gamma = .996# The exponential decay factor (adjust as needed)
#scheduler1 = CosineAnnealingWarmRestarts(optimizer1, 200, 2)
scheduler = ExponentialLR(optimizer, gamma=gamma)
torch.cuda.empty_cache()
gc.collect()

# Training loop
num_epochs = 400
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for im,speed,scale1, scale2 in dataloader:
        # Forward pass
        optimizer.zero_grad()
        outputs, out1, out2 = model(im.to(device))
        #outputs2 = model2(outputs.to(device))
        # loss_xt = criterion(outputs[:,0,:].squeeze(), xt.squeeze().to(device))
        # loss_lab = criterion(outputs[:,1,:].squeeze(), lab.squeeze().to(device))
        # loss = criterion(outputs.squeeze(), scale.squeeze().to(device))
        #loss_end = criterion(outputs[:,-20:], speed[:,-20:].to(device))
        loss_mse = criterion(outputs, speed.to(device))
        ls1 = criterion(out1.squeeze(1), scale1.to(device))
        ls2 = criterion(out2.squeeze(1), scale2.to(device))
        #ls3 = criterion(out3.squeeze(1), scale3.to(device))
        #loss = loss_lab+loss_xt
        # Backward pass and optimization
        
        #optimizer2.zero_grad()
        loss = loss_mse+(ls1+ls2)*3
        loss.backward()
        optimizer.step()
        #optimizer2.step()
        scheduler.step()

        running_loss += loss.item()

    # Print the average loss for the epoch
    epoch_loss = running_loss / len(dataloader)
    model.eval()
    running_loss2=0
    running_loss3=0
    with torch.no_grad():
        for im_tst,speed_tst,s1,s2 in test_dataloader:
        # Forward pass
            outputs_tst,a_tst,b_tst = model(im_tst.to(device))
            # loss_xt = criterion(outputs_tst[:,0,:].squeeze(), xt_tst.squeeze().to(device))
            # loss_lab = criterion(outputs_tst[:,1,:].squeeze(), lab_tst.squeeze().to(device))
            # loss2 = criterion(outputs_tst.squeeze(), scale_tst.squeeze().to(device))
            ls1 = criterion(a_tst.squeeze(1), s1.to(device))
            ls2 = criterion(b_tst.squeeze(1), s2.to(device))
            #ls3 = criterion(c_tst.squeeze(1), s3.to(device))
            loss2 = criterion(outputs_tst, speed_tst.to(device))
            loss3 = (ls1+ls2)
            #loss2 = loss_lab+loss_xt

#             loss2 = criterion(outputs_tst.squeeze(), scale_tst.squeeze().to(device))

            running_loss2 += loss2.item()
            running_loss3 += loss3.item()
    epoch_loss2 = running_loss2 / len(test_dataloader)
    epoch_loss3 = running_loss3 / len(test_dataloader)
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {epoch_loss:.5f},  Test Loss: {epoch_loss2:.5f}, Test Loss Distribution Params: {epoch_loss3:.5f},Learning Rate: {optimizer.param_groups[0]['lr']:.7f}")
    torch.cuda.empty_cache()
    gc.collect()
print("Training finished!")
# Out:
# Epoch [1/400], Loss: 7225.84790,  Test Loss: 3492.21631, Test Loss Distribution Params: 1660.85004,Learning Rate: 0.0003968
# Epoch [2/400], Loss: 6395.77466,  Test Loss: 3433.61902, Test Loss Distribution Params: 1406.51349,Learning Rate: 0.0003936
# Epoch [3/400], Loss: 4918.64648,  Test Loss: 3152.08167, Test Loss Distribution Params: 885.96884,Learning Rate: 0.0003905
# Epoch [4/400], Loss: 2973.75220,  Test Loss: 1760.27136, Test Loss Distribution Params: 41.79017,Learning Rate: 0.0003874
# Epoch [5/400], Loss: 1654.48370,  Test Loss: 1247.11163, Test Loss Distribution Params: 1692.82880,Learning Rate: 0.0003843
# Epoch [6/400], Loss: 1660.53687,  Test Loss: 753.64783, Test Loss Distribution Params: 115.35452,Learning Rate: 0.0003812
# Epoch [7/400], Loss: 1071.53104,  Test Loss: 1666.38232, Test Loss Distribution Params: 674.85144,Learning Rate: 0.0003782
# Epoch [8/400], Loss: 573.66898,  Test Loss: 1477.65479, Test Loss Distribution Params: 734.17233,Learning Rate: 0.0003752
# Epoch [9/400], Loss: 319.93362,  Test Loss: 896.68616, Test Loss Distribution Params: 556.05916,Learning Rate: 0.0003722
# Epoch [10/400], Loss: 331.13818,  Test Loss: 712.41595, Test Loss Distribution Params: 507.98152,Learning Rate: 0.0003692
# Epoch [11/400], Loss: 341.95021,  Test Loss: 817.75626, Test Loss Distribution Params: 549.07539,Learning Rate: 0.0003662
# Epoch [12/400], Loss: 259.42863,  Test Loss: 911.35086, Test Loss Distribution Params: 553.35512,Learning Rate: 0.0003633
# Epoch [13/400], Loss: 208.51289,  Test Loss: 815.83142, Test Loss Distribution Params: 452.68085,Learning Rate: 0.0003604
# Epoch [14/400], Loss: 163.45030,  Test Loss: 622.66763, Test Loss Distribution Params: 297.48962,Learning Rate: 0.0003575
# Epoch [15/400], Loss: 133.69700,  Test Loss: 414.74948, Test Loss Distribution Params: 155.07632,Learning Rate: 0.0003547
# Epoch [16/400], Loss: 184.79800,  Test Loss: 403.57098, Test Loss Distribution Params: 131.49061,Learning Rate: 0.0003519
# Epoch [17/400], Loss: 127.23264,  Test Loss: 366.76814, Test Loss Distribution Params: 105.41248,Learning Rate: 0.0003490
# Epoch [18/400], Loss: 109.96949,  Test Loss: 309.48840, Test Loss Distribution Params: 89.60067,Learning Rate: 0.0003463
# Epoch [19/400], Loss: 133.66871,  Test Loss: 252.05068, Test Loss Distribution Params: 81.89571,Learning Rate: 0.0003435
# Epoch [20/400], Loss: 135.42055,  Test Loss: 158.61143, Test Loss Distribution Params: 58.87567,Learning Rate: 0.0003407
# Epoch [21/400], Loss: 87.37264,  Test Loss: 173.18012, Test Loss Distribution Params: 80.93653,Learning Rate: 0.0003380
# Epoch [22/400], Loss: 83.16766,  Test Loss: 182.50639, Test Loss Distribution Params: 94.85485,Learning Rate: 0.0003353
# Epoch [23/400], Loss: 84.87521,  Test Loss: 141.93011, Test Loss Distribution Params: 71.53472,Learning Rate: 0.0003327
# Epoch [24/400], Loss: 75.43658,  Test Loss: 107.73714, Test Loss Distribution Params: 44.68665,Learning Rate: 0.0003300
# Epoch [25/400], Loss: 78.65906,  Test Loss: 127.15693, Test Loss Distribution Params: 51.80373,Learning Rate: 0.0003274
# Epoch [26/400], Loss: 74.32911,  Test Loss: 189.61690, Test Loss Distribution Params: 74.90661,Learning Rate: 0.0003247
# Epoch [27/400], Loss: 67.30630,  Test Loss: 202.71793, Test Loss Distribution Params: 74.32739,Learning Rate: 0.0003222
# Epoch [28/400], Loss: 96.43525,  Test Loss: 182.48817, Test Loss Distribution Params: 62.67131,Learning Rate: 0.0003196
# Epoch [29/400], Loss: 65.30277,  Test Loss: 124.77554, Test Loss Distribution Params: 37.30078,Learning Rate: 0.0003170
# Epoch [30/400], Loss: 83.60571,  Test Loss: 113.99725, Test Loss Distribution Params: 33.47209,Learning Rate: 0.0003145
# Epoch [31/400], Loss: 76.47570,  Test Loss: 136.30206, Test Loss Distribution Params: 41.91687,Learning Rate: 0.0003120
# Epoch [32/400], Loss: 67.25947,  Test Loss: 129.87153, Test Loss Distribution Params: 38.45985,Learning Rate: 0.0003095
# Epoch [33/400], Loss: 74.42860,  Test Loss: 100.69452, Test Loss Distribution Params: 19.33410,Learning Rate: 0.0003070
# Epoch [34/400], Loss: 77.85746,  Test Loss: 98.68735, Test Loss Distribution Params: 17.54628,Learning Rate: 0.0003046
# Epoch [35/400], Loss: 76.11402,  Test Loss: 139.33970, Test Loss Distribution Params: 42.23221,Learning Rate: 0.0003021
# Epoch [36/400], Loss: 77.29585,  Test Loss: 154.45297, Test Loss Distribution Params: 51.81678,Learning Rate: 0.0002997
# Epoch [37/400], Loss: 78.57916,  Test Loss: 107.05375, Test Loss Distribution Params: 24.96095,Learning Rate: 0.0002973
# Epoch [38/400], Loss: 60.72869,  Test Loss: 83.45314, Test Loss Distribution Params: 8.66124,Learning Rate: 0.0002950
# Epoch [39/400], Loss: 74.58009,  Test Loss: 83.82313, Test Loss Distribution Params: 6.01558,Learning Rate: 0.0002926
# Epoch [40/400], Loss: 68.89932,  Test Loss: 100.26078, Test Loss Distribution Params: 13.99906,Learning Rate: 0.0002903
# Epoch [41/400], Loss: 97.71483,  Test Loss: 118.83550, Test Loss Distribution Params: 19.00575,Learning Rate: 0.0002880
# Epoch [42/400], Loss: 69.36586,  Test Loss: 95.70408, Test Loss Distribution Params: 7.78768,Learning Rate: 0.0002857
# Epoch [43/400], Loss: 67.20378,  Test Loss: 95.54543, Test Loss Distribution Params: 5.47751,Learning Rate: 0.0002834
# Epoch [44/400], Loss: 64.84692,  Test Loss: 88.37821, Test Loss Distribution Params: 7.14417,Learning Rate: 0.0002811
# Epoch [45/400], Loss: 62.98400,  Test Loss: 100.15421, Test Loss Distribution Params: 18.66936,Learning Rate: 0.0002789
# Epoch [46/400], Loss: 60.67207,  Test Loss: 113.05370, Test Loss Distribution Params: 27.44014,Learning Rate: 0.0002766
# Epoch [47/400], Loss: 56.94082,  Test Loss: 122.68092, Test Loss Distribution Params: 32.51188,Learning Rate: 0.0002744
# Epoch [48/400], Loss: 59.88231,  Test Loss: 135.54743, Test Loss Distribution Params: 37.13990,Learning Rate: 0.0002722
# Epoch [49/400], Loss: 59.92186,  Test Loss: 118.52005, Test Loss Distribution Params: 27.34956,Learning Rate: 0.0002701
# Epoch [50/400], Loss: 59.50138,  Test Loss: 103.51116, Test Loss Distribution Params: 18.83646,Learning Rate: 0.0002679
# Epoch [51/400], Loss: 62.11053,  Test Loss: 92.30287, Test Loss Distribution Params: 11.66370,Learning Rate: 0.0002658
# Epoch [52/400], Loss: 62.12933,  Test Loss: 85.66003, Test Loss Distribution Params: 6.69108,Learning Rate: 0.0002637
# Epoch [53/400], Loss: 57.42510,  Test Loss: 83.68760, Test Loss Distribution Params: 6.10494,Learning Rate: 0.0002615
# Epoch [54/400], Loss: 58.32996,  Test Loss: 87.91928, Test Loss Distribution Params: 9.12992,Learning Rate: 0.0002595
# Epoch [55/400], Loss: 60.61985,  Test Loss: 91.36675, Test Loss Distribution Params: 13.39900,Learning Rate: 0.0002574
# Epoch [56/400], Loss: 57.31220,  Test Loss: 94.35756, Test Loss Distribution Params: 15.29566,Learning Rate: 0.0002553
# Epoch [57/400], Loss: 59.45179,  Test Loss: 94.53751, Test Loss Distribution Params: 13.15588,Learning Rate: 0.0002533
# Epoch [58/400], Loss: 65.05389,  Test Loss: 81.15635, Test Loss Distribution Params: 5.91689,Learning Rate: 0.0002513
# Epoch [59/400], Loss: 61.33630,  Test Loss: 81.96325, Test Loss Distribution Params: 5.63251,Learning Rate: 0.0002493
# Epoch [60/400], Loss: 73.55981,  Test Loss: 81.03693, Test Loss Distribution Params: 5.72653,Learning Rate: 0.0002473
# Epoch [61/400], Loss: 57.49780,  Test Loss: 83.65261, Test Loss Distribution Params: 5.76602,Learning Rate: 0.0002453
# Epoch [62/400], Loss: 56.86401,  Test Loss: 87.16730, Test Loss Distribution Params: 7.31902,Learning Rate: 0.0002433
# Epoch [63/400], Loss: 58.60642,  Test Loss: 87.62901, Test Loss Distribution Params: 8.27096,Learning Rate: 0.0002414
# Epoch [64/400], Loss: 76.46801,  Test Loss: 93.65901, Test Loss Distribution Params: 13.21170,Learning Rate: 0.0002395
# Epoch [65/400], Loss: 57.92011,  Test Loss: 101.71465, Test Loss Distribution Params: 16.87422,Learning Rate: 0.0002376
# Epoch [66/400], Loss: 66.57345,  Test Loss: 101.96051, Test Loss Distribution Params: 17.19638,Learning Rate: 0.0002357
# Epoch [67/400], Loss: 69.93428,  Test Loss: 96.48628, Test Loss Distribution Params: 14.27936,Learning Rate: 0.0002338
# Epoch [68/400], Loss: 71.77584,  Test Loss: 96.83180, Test Loss Distribution Params: 15.25270,Learning Rate: 0.0002319
# Epoch [69/400], Loss: 57.71626,  Test Loss: 117.31815, Test Loss Distribution Params: 25.53353,Learning Rate: 0.0002301
# Epoch [70/400], Loss: 58.50528,  Test Loss: 129.05104, Test Loss Distribution Params: 30.61162,Learning Rate: 0.0002282
# Epoch [71/400], Loss: 61.07469,  Test Loss: 106.42250, Test Loss Distribution Params: 20.62829,Learning Rate: 0.0002264
# Epoch [72/400], Loss: 57.85503,  Test Loss: 94.20102, Test Loss Distribution Params: 15.61471,Learning Rate: 0.0002246
# Epoch [73/400], Loss: 76.72292,  Test Loss: 105.14531, Test Loss Distribution Params: 22.51835,Learning Rate: 0.0002228
# Epoch [74/400], Loss: 54.29021,  Test Loss: 104.65753, Test Loss Distribution Params: 22.44831,Learning Rate: 0.0002210
# Epoch [75/400], Loss: 59.98522,  Test Loss: 98.40152, Test Loss Distribution Params: 17.75668,Learning Rate: 0.0002193
# Epoch [76/400], Loss: 60.46022,  Test Loss: 88.52912, Test Loss Distribution Params: 10.95172,Learning Rate: 0.0002175
# Epoch [77/400], Loss: 63.00821,  Test Loss: 90.11859, Test Loss Distribution Params: 9.71148,Learning Rate: 0.0002158
# Epoch [78/400], Loss: 57.43006,  Test Loss: 100.56654, Test Loss Distribution Params: 14.41487,Learning Rate: 0.0002141
# Epoch [79/400], Loss: 54.21561,  Test Loss: 102.24571, Test Loss Distribution Params: 15.30912,Learning Rate: 0.0002123
# Epoch [80/400], Loss: 58.03205,  Test Loss: 96.21749, Test Loss Distribution Params: 13.79677,Learning Rate: 0.0002106
# Epoch [81/400], Loss: 52.39069,  Test Loss: 86.43494, Test Loss Distribution Params: 9.59181,Learning Rate: 0.0002090
# Epoch [82/400], Loss: 54.66252,  Test Loss: 85.51284, Test Loss Distribution Params: 9.71635,Learning Rate: 0.0002073
# Epoch [83/400], Loss: 58.61590,  Test Loss: 87.24359, Test Loss Distribution Params: 11.06031,Learning Rate: 0.0002056
# Epoch [84/400], Loss: 53.55756,  Test Loss: 89.95780, Test Loss Distribution Params: 11.68264,Learning Rate: 0.0002040
# Epoch [85/400], Loss: 66.32352,  Test Loss: 91.09086, Test Loss Distribution Params: 11.58442,Learning Rate: 0.0002024
# Epoch [86/400], Loss: 53.43367,  Test Loss: 87.51432, Test Loss Distribution Params: 8.58306,Learning Rate: 0.0002008
# Epoch [87/400], Loss: 62.91637,  Test Loss: 84.34983, Test Loss Distribution Params: 7.66910,Learning Rate: 0.0001992
# Epoch [88/400], Loss: 58.08305,  Test Loss: 89.08094, Test Loss Distribution Params: 11.42946,Learning Rate: 0.0001976
# Epoch [89/400], Loss: 62.88508,  Test Loss: 111.85766, Test Loss Distribution Params: 20.05623,Learning Rate: 0.0001960
# Epoch [90/400], Loss: 60.16645,  Test Loss: 102.92373, Test Loss Distribution Params: 15.77521,Learning Rate: 0.0001944
# Epoch [91/400], Loss: 54.06880,  Test Loss: 86.23328, Test Loss Distribution Params: 7.66855,Learning Rate: 0.0001929
# Epoch [92/400], Loss: 55.30366,  Test Loss: 85.62997, Test Loss Distribution Params: 6.45709,Learning Rate: 0.0001913
# Epoch [93/400], Loss: 59.09865,  Test Loss: 89.11512, Test Loss Distribution Params: 9.14378,Learning Rate: 0.0001898
# Epoch [94/400], Loss: 56.95190,  Test Loss: 100.96687, Test Loss Distribution Params: 14.94537,Learning Rate: 0.0001883
# Epoch [95/400], Loss: 62.04842,  Test Loss: 94.14249, Test Loss Distribution Params: 12.59981,Learning Rate: 0.0001868
# Epoch [96/400], Loss: 64.68535,  Test Loss: 85.62829, Test Loss Distribution Params: 8.26775,Learning Rate: 0.0001853
# Epoch [97/400], Loss: 61.35763,  Test Loss: 86.82149, Test Loss Distribution Params: 9.31244,Learning Rate: 0.0001838
# Epoch [98/400], Loss: 66.61458,  Test Loss: 103.03881, Test Loss Distribution Params: 16.59306,Learning Rate: 0.0001823
# Epoch [99/400], Loss: 56.24704,  Test Loss: 142.05059, Test Loss Distribution Params: 32.57408,Learning Rate: 0.0001809
# Epoch [100/400], Loss: 68.62742,  Test Loss: 124.59675, Test Loss Distribution Params: 26.79464,Learning Rate: 0.0001794
# Epoch [101/400], Loss: 59.71803,  Test Loss: 87.47303, Test Loss Distribution Params: 10.95279,Learning Rate: 0.0001780
# Epoch [102/400], Loss: 68.87736,  Test Loss: 80.80844, Test Loss Distribution Params: 5.41701,Learning Rate: 0.0001766
# Epoch [103/400], Loss: 69.29116,  Test Loss: 89.09300, Test Loss Distribution Params: 9.58482,Learning Rate: 0.0001752
# Epoch [104/400], Loss: 53.36555,  Test Loss: 103.73880, Test Loss Distribution Params: 14.13264,Learning Rate: 0.0001738
# Epoch [105/400], Loss: 54.93841,  Test Loss: 86.15356, Test Loss Distribution Params: 7.96232,Learning Rate: 0.0001724
# Epoch [106/400], Loss: 50.85693,  Test Loss: 79.74679, Test Loss Distribution Params: 6.43308,Learning Rate: 0.0001710
# Epoch [107/400], Loss: 50.87184,  Test Loss: 81.90395, Test Loss Distribution Params: 8.26626,Learning Rate: 0.0001697
# Epoch [108/400], Loss: 52.68883,  Test Loss: 86.68769, Test Loss Distribution Params: 10.89104,Learning Rate: 0.0001683
# Epoch [109/400], Loss: 63.68027,  Test Loss: 94.51486, Test Loss Distribution Params: 14.72337,Learning Rate: 0.0001670
# Epoch [110/400], Loss: 55.32687,  Test Loss: 81.43486, Test Loss Distribution Params: 9.30343,Learning Rate: 0.0001656
# Epoch [111/400], Loss: 48.94390,  Test Loss: 76.12693, Test Loss Distribution Params: 7.16771,Learning Rate: 0.0001643
# Epoch [112/400], Loss: 56.81917,  Test Loss: 76.12404, Test Loss Distribution Params: 7.52831,Learning Rate: 0.0001630
# Epoch [113/400], Loss: 51.71527,  Test Loss: 76.09394, Test Loss Distribution Params: 6.83563,Learning Rate: 0.0001617
# Epoch [114/400], Loss: 56.22390,  Test Loss: 69.74621, Test Loss Distribution Params: 4.21368,Learning Rate: 0.0001604
# Epoch [115/400], Loss: 54.57065,  Test Loss: 71.26702, Test Loss Distribution Params: 4.34758,Learning Rate: 0.0001591
# Epoch [116/400], Loss: 53.58182,  Test Loss: 75.84237, Test Loss Distribution Params: 6.40473,Learning Rate: 0.0001578
# Epoch [117/400], Loss: 53.22824,  Test Loss: 92.20721, Test Loss Distribution Params: 12.98315,Learning Rate: 0.0001566
# Epoch [118/400], Loss: 50.75342,  Test Loss: 99.32141, Test Loss Distribution Params: 16.83425,Learning Rate: 0.0001553
# Epoch [119/400], Loss: 47.59035,  Test Loss: 99.83804, Test Loss Distribution Params: 18.43801,Learning Rate: 0.0001541
# Epoch [120/400], Loss: 48.48465,  Test Loss: 95.01579, Test Loss Distribution Params: 18.22173,Learning Rate: 0.0001529
# Epoch [121/400], Loss: 48.08946,  Test Loss: 86.96772, Test Loss Distribution Params: 16.04412,Learning Rate: 0.0001516
# Epoch [122/400], Loss: 48.51493,  Test Loss: 92.48266, Test Loss Distribution Params: 18.11583,Learning Rate: 0.0001504
# Epoch [123/400], Loss: 48.36175,  Test Loss: 99.96450, Test Loss Distribution Params: 20.20230,Learning Rate: 0.0001492
# Epoch [124/400], Loss: 48.11684,  Test Loss: 103.59686, Test Loss Distribution Params: 20.57200,Learning Rate: 0.0001480
# Epoch [125/400], Loss: 56.10493,  Test Loss: 89.08241, Test Loss Distribution Params: 13.71420,Learning Rate: 0.0001469
# Epoch [126/400], Loss: 53.15974,  Test Loss: 86.21467, Test Loss Distribution Params: 12.34623,Learning Rate: 0.0001457
# Epoch [127/400], Loss: 45.62522,  Test Loss: 73.93661, Test Loss Distribution Params: 8.42570,Learning Rate: 0.0001445
# Epoch [128/400], Loss: 45.99531,  Test Loss: 74.08869, Test Loss Distribution Params: 10.09079,Learning Rate: 0.0001434
# Epoch [129/400], Loss: 44.35160,  Test Loss: 74.63203, Test Loss Distribution Params: 11.90891,Learning Rate: 0.0001422
# Epoch [130/400], Loss: 44.59237,  Test Loss: 77.58169, Test Loss Distribution Params: 13.52436,Learning Rate: 0.0001411
# Epoch [131/400], Loss: 44.12723,  Test Loss: 83.56951, Test Loss Distribution Params: 16.37967,Learning Rate: 0.0001400
# Epoch [132/400], Loss: 42.23548,  Test Loss: 90.20688, Test Loss Distribution Params: 19.80640,Learning Rate: 0.0001388
# Epoch [133/400], Loss: 42.72297,  Test Loss: 93.05437, Test Loss Distribution Params: 21.58647,Learning Rate: 0.0001377
# Epoch [134/400], Loss: 44.05343,  Test Loss: 97.90436, Test Loss Distribution Params: 24.55969,Learning Rate: 0.0001366
# Epoch [135/400], Loss: 42.25760,  Test Loss: 97.67888, Test Loss Distribution Params: 24.91645,Learning Rate: 0.0001355
# Epoch [136/400], Loss: 43.21172,  Test Loss: 102.17453, Test Loss Distribution Params: 26.93714,Learning Rate: 0.0001345
# Epoch [137/400], Loss: 59.33135,  Test Loss: 104.97002, Test Loss Distribution Params: 28.39874,Learning Rate: 0.0001334
# Epoch [138/400], Loss: 41.43135,  Test Loss: 112.28237, Test Loss Distribution Params: 31.85635,Learning Rate: 0.0001323
# Epoch [139/400], Loss: 41.63060,  Test Loss: 125.77720, Test Loss Distribution Params: 38.74122,Learning Rate: 0.0001313
# Epoch [140/400], Loss: 42.59084,  Test Loss: 141.67212, Test Loss Distribution Params: 47.35606,Learning Rate: 0.0001302
# Epoch [141/400], Loss: 45.44050,  Test Loss: 170.27801, Test Loss Distribution Params: 59.36720,Learning Rate: 0.0001292
# Epoch [142/400], Loss: 42.98362,  Test Loss: 167.98587, Test Loss Distribution Params: 59.90101,Learning Rate: 0.0001281
# Epoch [143/400], Loss: 38.77780,  Test Loss: 148.99339, Test Loss Distribution Params: 51.94957,Learning Rate: 0.0001271
# Epoch [144/400], Loss: 38.90070,  Test Loss: 146.73946, Test Loss Distribution Params: 49.91910,Learning Rate: 0.0001261
# Epoch [145/400], Loss: 41.50759,  Test Loss: 146.24209, Test Loss Distribution Params: 47.96546,Learning Rate: 0.0001251
# Epoch [146/400], Loss: 38.46711,  Test Loss: 154.72849, Test Loss Distribution Params: 50.49471,Learning Rate: 0.0001241
# Epoch [147/400], Loss: 37.82960,  Test Loss: 151.25329, Test Loss Distribution Params: 48.56947,Learning Rate: 0.0001231
# Epoch [148/400], Loss: 35.38310,  Test Loss: 143.98080, Test Loss Distribution Params: 47.07019,Learning Rate: 0.0001221
# Epoch [149/400], Loss: 34.44489,  Test Loss: 142.88366, Test Loss Distribution Params: 48.48746,Learning Rate: 0.0001212
# Epoch [150/400], Loss: 36.10187,  Test Loss: 161.24878, Test Loss Distribution Params: 58.40726,Learning Rate: 0.0001202
# Epoch [151/400], Loss: 37.66747,  Test Loss: 162.71482, Test Loss Distribution Params: 60.14262,Learning Rate: 0.0001192
# Epoch [152/400], Loss: 36.32356,  Test Loss: 139.22427, Test Loss Distribution Params: 48.53465,Learning Rate: 0.0001183
# Epoch [153/400], Loss: 36.94004,  Test Loss: 98.80770, Test Loss Distribution Params: 30.58098,Learning Rate: 0.0001173
# Epoch [154/400], Loss: 38.97284,  Test Loss: 86.43937, Test Loss Distribution Params: 25.15501,Learning Rate: 0.0001164
# Epoch [155/400], Loss: 31.00989,  Test Loss: 59.63500, Test Loss Distribution Params: 12.52280,Learning Rate: 0.0001155
# Epoch [156/400], Loss: 32.27506,  Test Loss: 48.75467, Test Loss Distribution Params: 7.46644,Learning Rate: 0.0001145
# Epoch [157/400], Loss: 29.61114,  Test Loss: 47.48144, Test Loss Distribution Params: 6.92029,Learning Rate: 0.0001136
# Epoch [158/400], Loss: 28.08699,  Test Loss: 50.10376, Test Loss Distribution Params: 8.54867,Learning Rate: 0.0001127
# Epoch [159/400], Loss: 30.99578,  Test Loss: 52.41778, Test Loss Distribution Params: 10.90315,Learning Rate: 0.0001118
# Epoch [160/400], Loss: 32.63241,  Test Loss: 54.31200, Test Loss Distribution Params: 12.29489,Learning Rate: 0.0001109
# Epoch [161/400], Loss: 27.24546,  Test Loss: 53.02785, Test Loss Distribution Params: 12.26341,Learning Rate: 0.0001100
# Epoch [162/400], Loss: 27.08758,  Test Loss: 59.69091, Test Loss Distribution Params: 15.09643,Learning Rate: 0.0001092
# Epoch [163/400], Loss: 24.35685,  Test Loss: 68.49914, Test Loss Distribution Params: 18.60010,Learning Rate: 0.0001083
# Epoch [164/400], Loss: 27.06408,  Test Loss: 68.61853, Test Loss Distribution Params: 18.79991,Learning Rate: 0.0001074
# Epoch [165/400], Loss: 42.44334,  Test Loss: 68.04337, Test Loss Distribution Params: 19.31409,Learning Rate: 0.0001066
# Epoch [166/400], Loss: 26.69276,  Test Loss: 48.03634, Test Loss Distribution Params: 11.43425,Learning Rate: 0.0001057
# Epoch [167/400], Loss: 28.29822,  Test Loss: 42.52715, Test Loss Distribution Params: 9.40848,Learning Rate: 0.0001049
# Epoch [168/400], Loss: 26.82787,  Test Loss: 39.39612, Test Loss Distribution Params: 8.48464,Learning Rate: 0.0001040
# Epoch [169/400], Loss: 23.63596,  Test Loss: 44.07610, Test Loss Distribution Params: 11.33805,Learning Rate: 0.0001032
# Epoch [170/400], Loss: 26.33836,  Test Loss: 59.08556, Test Loss Distribution Params: 17.79752,Learning Rate: 0.0001024
# Epoch [171/400], Loss: 21.44350,  Test Loss: 78.17150, Test Loss Distribution Params: 24.92564,Learning Rate: 0.0001016
# Epoch [172/400], Loss: 39.40715,  Test Loss: 64.98797, Test Loss Distribution Params: 19.20241,Learning Rate: 0.0001008
# Epoch [173/400], Loss: 36.29539,  Test Loss: 45.05209, Test Loss Distribution Params: 11.46290,Learning Rate: 0.0001000
# Epoch [174/400], Loss: 33.12956,  Test Loss: 43.56149, Test Loss Distribution Params: 10.96047,Learning Rate: 0.0000992
# Epoch [175/400], Loss: 31.23969,  Test Loss: 45.71470, Test Loss Distribution Params: 12.61428,Learning Rate: 0.0000984
# Epoch [176/400], Loss: 25.41409,  Test Loss: 86.29097, Test Loss Distribution Params: 31.61299,Learning Rate: 0.0000976
# Epoch [177/400], Loss: 19.57798,  Test Loss: 149.16425, Test Loss Distribution Params: 60.56439,Learning Rate: 0.0000968
# Epoch [178/400], Loss: 22.21113,  Test Loss: 169.21662, Test Loss Distribution Params: 70.65829,Learning Rate: 0.0000960
# Epoch [179/400], Loss: 22.03358,  Test Loss: 153.08704, Test Loss Distribution Params: 64.52719,Learning Rate: 0.0000953
# Epoch [180/400], Loss: 17.14086,  Test Loss: 114.06149, Test Loss Distribution Params: 45.90010,Learning Rate: 0.0000945
# Epoch [181/400], Loss: 26.07638,  Test Loss: 92.20079, Test Loss Distribution Params: 35.33816,Learning Rate: 0.0000937
# Epoch [182/400], Loss: 24.73770,  Test Loss: 65.37774, Test Loss Distribution Params: 22.46904,Learning Rate: 0.0000930
# Epoch [183/400], Loss: 19.43573,  Test Loss: 52.97191, Test Loss Distribution Params: 15.54098,Learning Rate: 0.0000923
# Epoch [184/400], Loss: 24.79276,  Test Loss: 49.22442, Test Loss Distribution Params: 12.87292,Learning Rate: 0.0000915
# Epoch [185/400], Loss: 26.76571,  Test Loss: 41.35523, Test Loss Distribution Params: 9.84187,Learning Rate: 0.0000908
# Epoch [186/400], Loss: 17.74696,  Test Loss: 34.54777, Test Loss Distribution Params: 7.17862,Learning Rate: 0.0000901
# Epoch [187/400], Loss: 14.64693,  Test Loss: 29.99351, Test Loss Distribution Params: 5.93557,Learning Rate: 0.0000893
# Epoch [188/400], Loss: 18.13627,  Test Loss: 26.28935, Test Loss Distribution Params: 4.91185,Learning Rate: 0.0000886
# Epoch [189/400], Loss: 20.15498,  Test Loss: 25.98261, Test Loss Distribution Params: 4.91147,Learning Rate: 0.0000879
# Epoch [190/400], Loss: 30.90249,  Test Loss: 31.32762, Test Loss Distribution Params: 8.16188,Learning Rate: 0.0000872
# Epoch [191/400], Loss: 18.66379,  Test Loss: 39.48794, Test Loss Distribution Params: 13.05965,Learning Rate: 0.0000865
# Epoch [192/400], Loss: 28.47941,  Test Loss: 44.12351, Test Loss Distribution Params: 15.26738,Learning Rate: 0.0000858
# Epoch [193/400], Loss: 17.24162,  Test Loss: 44.58690, Test Loss Distribution Params: 14.97190,Learning Rate: 0.0000851
# Epoch [194/400], Loss: 22.06323,  Test Loss: 48.25146, Test Loss Distribution Params: 15.67112,Learning Rate: 0.0000845
# Epoch [195/400], Loss: 15.52501,  Test Loss: 50.00062, Test Loss Distribution Params: 15.99804,Learning Rate: 0.0000838
# Epoch [196/400], Loss: 16.86436,  Test Loss: 62.16104, Test Loss Distribution Params: 20.97324,Learning Rate: 0.0000831
# Epoch [197/400], Loss: 14.83609,  Test Loss: 62.00100, Test Loss Distribution Params: 21.07076,Learning Rate: 0.0000825
# Epoch [198/400], Loss: 15.55976,  Test Loss: 52.74311, Test Loss Distribution Params: 17.51841,Learning Rate: 0.0000818
# Epoch [199/400], Loss: 13.92489,  Test Loss: 44.92975, Test Loss Distribution Params: 14.75596,Learning Rate: 0.0000811
# Epoch [200/400], Loss: 13.99154,  Test Loss: 39.88953, Test Loss Distribution Params: 13.16129,Learning Rate: 0.0000805
# Epoch [201/400], Loss: 19.74414,  Test Loss: 46.33590, Test Loss Distribution Params: 15.98772,Learning Rate: 0.0000799
# Epoch [202/400], Loss: 14.51815,  Test Loss: 49.30962, Test Loss Distribution Params: 17.05558,Learning Rate: 0.0000792
# Epoch [203/400], Loss: 16.39306,  Test Loss: 49.09240, Test Loss Distribution Params: 17.02029,Learning Rate: 0.0000786
# Epoch [204/400], Loss: 15.27032,  Test Loss: 45.55451, Test Loss Distribution Params: 15.50132,Learning Rate: 0.0000780
# Epoch [205/400], Loss: 14.36727,  Test Loss: 41.35538, Test Loss Distribution Params: 13.77759,Learning Rate: 0.0000773
# Epoch [206/400], Loss: 13.94595,  Test Loss: 40.23912, Test Loss Distribution Params: 13.62137,Learning Rate: 0.0000767
# Epoch [207/400], Loss: 17.20550,  Test Loss: 37.58394, Test Loss Distribution Params: 12.45316,Learning Rate: 0.0000761
# Epoch [208/400], Loss: 13.13896,  Test Loss: 34.72315, Test Loss Distribution Params: 10.80272,Learning Rate: 0.0000755
# Epoch [209/400], Loss: 13.34801,  Test Loss: 31.18796, Test Loss Distribution Params: 8.81251,Learning Rate: 0.0000749
# Epoch [210/400], Loss: 15.80745,  Test Loss: 32.13697, Test Loss Distribution Params: 9.23049,Learning Rate: 0.0000743
# Epoch [211/400], Loss: 12.56295,  Test Loss: 33.41683, Test Loss Distribution Params: 10.17900,Learning Rate: 0.0000737
# Epoch [212/400], Loss: 14.52224,  Test Loss: 46.93300, Test Loss Distribution Params: 17.39419,Learning Rate: 0.0000731
# Epoch [213/400], Loss: 13.98413,  Test Loss: 51.33840, Test Loss Distribution Params: 19.51851,Learning Rate: 0.0000725
# Epoch [214/400], Loss: 14.76504,  Test Loss: 56.87915, Test Loss Distribution Params: 22.16472,Learning Rate: 0.0000720
# Epoch [215/400], Loss: 18.06259,  Test Loss: 60.65477, Test Loss Distribution Params: 23.87461,Learning Rate: 0.0000714
# Epoch [216/400], Loss: 23.54427,  Test Loss: 56.59076, Test Loss Distribution Params: 22.20169,Learning Rate: 0.0000708
# Epoch [217/400], Loss: 15.79124,  Test Loss: 49.85755, Test Loss Distribution Params: 18.91421,Learning Rate: 0.0000702
# Epoch [218/400], Loss: 12.73987,  Test Loss: 46.24280, Test Loss Distribution Params: 17.52951,Learning Rate: 0.0000697
# Epoch [219/400], Loss: 14.36661,  Test Loss: 41.17015, Test Loss Distribution Params: 15.46268,Learning Rate: 0.0000691
# Epoch [220/400], Loss: 16.27217,  Test Loss: 43.84245, Test Loss Distribution Params: 15.89855,Learning Rate: 0.0000686
# Epoch [221/400], Loss: 12.93143,  Test Loss: 44.20351, Test Loss Distribution Params: 14.93826,Learning Rate: 0.0000680
# Epoch [222/400], Loss: 13.04702,  Test Loss: 41.86604, Test Loss Distribution Params: 13.57018,Learning Rate: 0.0000675
# Epoch [223/400], Loss: 12.50384,  Test Loss: 32.86251, Test Loss Distribution Params: 9.38920,Learning Rate: 0.0000669
# Epoch [224/400], Loss: 13.61133,  Test Loss: 28.44294, Test Loss Distribution Params: 7.34752,Learning Rate: 0.0000664
# Epoch [225/400], Loss: 11.57386,  Test Loss: 26.12486, Test Loss Distribution Params: 6.17951,Learning Rate: 0.0000659
# Epoch [226/400], Loss: 14.03716,  Test Loss: 25.90739, Test Loss Distribution Params: 5.99040,Learning Rate: 0.0000654
# Epoch [227/400], Loss: 14.54337,  Test Loss: 26.50856, Test Loss Distribution Params: 6.35878,Learning Rate: 0.0000648
# Epoch [228/400], Loss: 12.08251,  Test Loss: 27.01261, Test Loss Distribution Params: 6.67173,Learning Rate: 0.0000643
# Epoch [229/400], Loss: 18.61567,  Test Loss: 27.02573, Test Loss Distribution Params: 6.72536,Learning Rate: 0.0000638
# Epoch [230/400], Loss: 11.73791,  Test Loss: 25.51141, Test Loss Distribution Params: 5.96895,Learning Rate: 0.0000633
# Epoch [231/400], Loss: 22.43102,  Test Loss: 27.13646, Test Loss Distribution Params: 7.10510,Learning Rate: 0.0000628
# Epoch [232/400], Loss: 11.41536,  Test Loss: 27.94482, Test Loss Distribution Params: 7.69079,Learning Rate: 0.0000623
# Epoch [233/400], Loss: 14.17155,  Test Loss: 30.40243, Test Loss Distribution Params: 9.17732,Learning Rate: 0.0000618
# Epoch [234/400], Loss: 11.92496,  Test Loss: 33.79081, Test Loss Distribution Params: 10.76894,Learning Rate: 0.0000613
# Epoch [235/400], Loss: 12.96298,  Test Loss: 32.27220, Test Loss Distribution Params: 9.72440,Learning Rate: 0.0000608
# Epoch [236/400], Loss: 19.67245,  Test Loss: 29.26118, Test Loss Distribution Params: 7.93560,Learning Rate: 0.0000603
# Epoch [237/400], Loss: 11.69103,  Test Loss: 25.23712, Test Loss Distribution Params: 5.71052,Learning Rate: 0.0000598
# Epoch [238/400], Loss: 11.49619,  Test Loss: 24.31191, Test Loss Distribution Params: 5.20326,Learning Rate: 0.0000594
# Epoch [239/400], Loss: 11.90173,  Test Loss: 24.29309, Test Loss Distribution Params: 5.14140,Learning Rate: 0.0000589
# Epoch [240/400], Loss: 18.74248,  Test Loss: 24.20075, Test Loss Distribution Params: 5.12370,Learning Rate: 0.0000584
# Epoch [241/400], Loss: 12.10554,  Test Loss: 23.16208, Test Loss Distribution Params: 4.66208,Learning Rate: 0.0000580
# Epoch [242/400], Loss: 11.83651,  Test Loss: 23.89049, Test Loss Distribution Params: 5.08501,Learning Rate: 0.0000575
# Epoch [243/400], Loss: 12.46987,  Test Loss: 23.80222, Test Loss Distribution Params: 5.01304,Learning Rate: 0.0000570
# Epoch [244/400], Loss: 10.61191,  Test Loss: 23.70679, Test Loss Distribution Params: 4.92381,Learning Rate: 0.0000566
# Epoch [245/400], Loss: 19.46021,  Test Loss: 24.12445, Test Loss Distribution Params: 5.08022,Learning Rate: 0.0000561
# Epoch [246/400], Loss: 11.98447,  Test Loss: 24.29525, Test Loss Distribution Params: 5.17263,Learning Rate: 0.0000557
# Epoch [247/400], Loss: 13.82882,  Test Loss: 25.19696, Test Loss Distribution Params: 5.51772,Learning Rate: 0.0000552
# Epoch [248/400], Loss: 12.75146,  Test Loss: 26.20105, Test Loss Distribution Params: 5.80720,Learning Rate: 0.0000548
# Epoch [249/400], Loss: 17.46617,  Test Loss: 25.79575, Test Loss Distribution Params: 5.56752,Learning Rate: 0.0000544
# Epoch [250/400], Loss: 25.80003,  Test Loss: 24.71473, Test Loss Distribution Params: 5.08326,Learning Rate: 0.0000539
# Epoch [251/400], Loss: 17.16017,  Test Loss: 26.05362, Test Loss Distribution Params: 5.81434,Learning Rate: 0.0000535
# Epoch [252/400], Loss: 18.55370,  Test Loss: 27.40964, Test Loss Distribution Params: 6.56635,Learning Rate: 0.0000531
# Epoch [253/400], Loss: 12.31408,  Test Loss: 28.36703, Test Loss Distribution Params: 7.26257,Learning Rate: 0.0000526
# Epoch [254/400], Loss: 12.84394,  Test Loss: 30.05454, Test Loss Distribution Params: 8.10020,Learning Rate: 0.0000522
# Epoch [255/400], Loss: 11.56668,  Test Loss: 30.06366, Test Loss Distribution Params: 8.17640,Learning Rate: 0.0000518
# Epoch [256/400], Loss: 15.92815,  Test Loss: 28.84872, Test Loss Distribution Params: 7.48140,Learning Rate: 0.0000514
# Epoch [257/400], Loss: 15.14921,  Test Loss: 28.59458, Test Loss Distribution Params: 7.34491,Learning Rate: 0.0000510
# Epoch [258/400], Loss: 13.07984,  Test Loss: 27.44173, Test Loss Distribution Params: 6.77039,Learning Rate: 0.0000506
# Epoch [259/400], Loss: 10.76633,  Test Loss: 27.68782, Test Loss Distribution Params: 6.92977,Learning Rate: 0.0000502
# Epoch [260/400], Loss: 11.78297,  Test Loss: 29.51750, Test Loss Distribution Params: 8.01216,Learning Rate: 0.0000498
# Epoch [261/400], Loss: 15.38747,  Test Loss: 30.75832, Test Loss Distribution Params: 8.84223,Learning Rate: 0.0000494
# Epoch [262/400], Loss: 15.24984,  Test Loss: 32.19588, Test Loss Distribution Params: 9.77654,Learning Rate: 0.0000490
# Epoch [263/400], Loss: 12.99497,  Test Loss: 32.43905, Test Loss Distribution Params: 10.14892,Learning Rate: 0.0000486
# Epoch [264/400], Loss: 13.45171,  Test Loss: 29.10393, Test Loss Distribution Params: 8.29010,Learning Rate: 0.0000482
# Epoch [265/400], Loss: 11.35111,  Test Loss: 27.43026, Test Loss Distribution Params: 7.18844,Learning Rate: 0.0000478
# Epoch [266/400], Loss: 10.84969,  Test Loss: 26.09299, Test Loss Distribution Params: 6.25423,Learning Rate: 0.0000474
# Epoch [267/400], Loss: 10.44892,  Test Loss: 25.80177, Test Loss Distribution Params: 5.97956,Learning Rate: 0.0000470
# Epoch [268/400], Loss: 14.43068,  Test Loss: 25.12604, Test Loss Distribution Params: 5.53427,Learning Rate: 0.0000467
# Epoch [269/400], Loss: 13.91993,  Test Loss: 24.01396, Test Loss Distribution Params: 4.98155,Learning Rate: 0.0000463
# Epoch [270/400], Loss: 11.69956,  Test Loss: 23.52742, Test Loss Distribution Params: 4.69202,Learning Rate: 0.0000459
# Epoch [271/400], Loss: 18.84339,  Test Loss: 23.23889, Test Loss Distribution Params: 4.47323,Learning Rate: 0.0000456
# Epoch [272/400], Loss: 11.27346,  Test Loss: 23.30860, Test Loss Distribution Params: 4.62304,Learning Rate: 0.0000452
# Epoch [273/400], Loss: 10.98556,  Test Loss: 23.33354, Test Loss Distribution Params: 4.70034,Learning Rate: 0.0000448
# Epoch [274/400], Loss: 13.06790,  Test Loss: 23.70043, Test Loss Distribution Params: 5.00026,Learning Rate: 0.0000445
# Epoch [275/400], Loss: 15.33744,  Test Loss: 25.51929, Test Loss Distribution Params: 5.93813,Learning Rate: 0.0000441
# Epoch [276/400], Loss: 15.26092,  Test Loss: 26.40454, Test Loss Distribution Params: 6.33552,Learning Rate: 0.0000438
# Epoch [277/400], Loss: 15.20780,  Test Loss: 29.30155, Test Loss Distribution Params: 8.09009,Learning Rate: 0.0000434
# Epoch [278/400], Loss: 11.55270,  Test Loss: 31.83392, Test Loss Distribution Params: 9.53235,Learning Rate: 0.0000431
# Epoch [279/400], Loss: 10.77667,  Test Loss: 30.59903, Test Loss Distribution Params: 8.84644,Learning Rate: 0.0000427
# Epoch [280/400], Loss: 26.10085,  Test Loss: 29.47799, Test Loss Distribution Params: 8.19733,Learning Rate: 0.0000424
# Epoch [281/400], Loss: 10.28725,  Test Loss: 27.96344, Test Loss Distribution Params: 7.23740,Learning Rate: 0.0000421
# Epoch [282/400], Loss: 11.14799,  Test Loss: 27.07257, Test Loss Distribution Params: 6.47640,Learning Rate: 0.0000417
# Epoch [283/400], Loss: 12.52264,  Test Loss: 27.19933, Test Loss Distribution Params: 6.88393,Learning Rate: 0.0000414
# Epoch [284/400], Loss: 10.07838,  Test Loss: 29.08432, Test Loss Distribution Params: 7.89687,Learning Rate: 0.0000411
# Epoch [285/400], Loss: 16.01405,  Test Loss: 31.84969, Test Loss Distribution Params: 8.95193,Learning Rate: 0.0000407
# Epoch [286/400], Loss: 11.41934,  Test Loss: 33.40033, Test Loss Distribution Params: 9.38630,Learning Rate: 0.0000404
# Epoch [287/400], Loss: 16.84255,  Test Loss: 34.71445, Test Loss Distribution Params: 10.19762,Learning Rate: 0.0000401
# Epoch [288/400], Loss: 10.74485,  Test Loss: 33.08544, Test Loss Distribution Params: 9.92379,Learning Rate: 0.0000398
# Epoch [289/400], Loss: 11.27715,  Test Loss: 31.04886, Test Loss Distribution Params: 8.98817,Learning Rate: 0.0000394
# Epoch [290/400], Loss: 12.27102,  Test Loss: 27.71803, Test Loss Distribution Params: 7.12162,Learning Rate: 0.0000391
# Epoch [291/400], Loss: 13.11681,  Test Loss: 26.95549, Test Loss Distribution Params: 6.65009,Learning Rate: 0.0000388
# Epoch [292/400], Loss: 10.92123,  Test Loss: 28.23729, Test Loss Distribution Params: 7.32167,Learning Rate: 0.0000385
# Epoch [293/400], Loss: 10.78029,  Test Loss: 29.18642, Test Loss Distribution Params: 7.84703,Learning Rate: 0.0000382
# Epoch [294/400], Loss: 12.54074,  Test Loss: 26.99605, Test Loss Distribution Params: 6.64653,Learning Rate: 0.0000379
# Epoch [295/400], Loss: 10.22273,  Test Loss: 26.73181, Test Loss Distribution Params: 6.48532,Learning Rate: 0.0000376
# Epoch [296/400], Loss: 12.93207,  Test Loss: 27.76903, Test Loss Distribution Params: 6.96826,Learning Rate: 0.0000373
# Epoch [297/400], Loss: 11.75192,  Test Loss: 30.26973, Test Loss Distribution Params: 8.32034,Learning Rate: 0.0000370
# Epoch [298/400], Loss: 10.21314,  Test Loss: 35.16337, Test Loss Distribution Params: 10.99996,Learning Rate: 0.0000367
# Epoch [299/400], Loss: 11.80823,  Test Loss: 38.69415, Test Loss Distribution Params: 12.84504,Learning Rate: 0.0000364
# Epoch [300/400], Loss: 12.04268,  Test Loss: 40.55927, Test Loss Distribution Params: 13.78366,Learning Rate: 0.0000361
# Epoch [301/400], Loss: 11.25619,  Test Loss: 39.58950, Test Loss Distribution Params: 13.32554,Learning Rate: 0.0000358
# Epoch [302/400], Loss: 14.13886,  Test Loss: 37.27027, Test Loss Distribution Params: 12.10923,Learning Rate: 0.0000355
# Epoch [303/400], Loss: 11.38711,  Test Loss: 35.92600, Test Loss Distribution Params: 11.42859,Learning Rate: 0.0000353
# Epoch [304/400], Loss: 12.44810,  Test Loss: 33.49548, Test Loss Distribution Params: 10.18717,Learning Rate: 0.0000350
# Epoch [305/400], Loss: 13.44089,  Test Loss: 31.17852, Test Loss Distribution Params: 9.07564,Learning Rate: 0.0000347
# Epoch [306/400], Loss: 13.29720,  Test Loss: 29.98033, Test Loss Distribution Params: 8.59251,Learning Rate: 0.0000344
# Epoch [307/400], Loss: 10.09643,  Test Loss: 29.72659, Test Loss Distribution Params: 8.57215,Learning Rate: 0.0000341
# Epoch [308/400], Loss: 17.93630,  Test Loss: 26.84019, Test Loss Distribution Params: 6.87506,Learning Rate: 0.0000339
# Epoch [309/400], Loss: 10.49610,  Test Loss: 25.29783, Test Loss Distribution Params: 5.88178,Learning Rate: 0.0000336
# Epoch [310/400], Loss: 12.44318,  Test Loss: 25.34017, Test Loss Distribution Params: 5.82532,Learning Rate: 0.0000333
# Epoch [311/400], Loss: 19.36554,  Test Loss: 25.29323, Test Loss Distribution Params: 5.76533,Learning Rate: 0.0000331
# Epoch [312/400], Loss: 10.28641,  Test Loss: 24.45490, Test Loss Distribution Params: 5.31135,Learning Rate: 0.0000328
# Epoch [313/400], Loss: 13.95401,  Test Loss: 24.23548, Test Loss Distribution Params: 5.10927,Learning Rate: 0.0000325
# Epoch [314/400], Loss: 9.91698,  Test Loss: 23.89976, Test Loss Distribution Params: 4.90129,Learning Rate: 0.0000323
# Epoch [315/400], Loss: 11.13247,  Test Loss: 23.63219, Test Loss Distribution Params: 4.65648,Learning Rate: 0.0000320
# Epoch [316/400], Loss: 10.77381,  Test Loss: 23.41311, Test Loss Distribution Params: 4.50626,Learning Rate: 0.0000318
# Epoch [317/400], Loss: 15.44511,  Test Loss: 23.92515, Test Loss Distribution Params: 4.76079,Learning Rate: 0.0000315
# Epoch [318/400], Loss: 10.39751,  Test Loss: 25.53110, Test Loss Distribution Params: 5.60573,Learning Rate: 0.0000313
# Epoch [319/400], Loss: 10.52845,  Test Loss: 28.42436, Test Loss Distribution Params: 7.14449,Learning Rate: 0.0000310
# Epoch [320/400], Loss: 11.92152,  Test Loss: 29.55946, Test Loss Distribution Params: 7.83064,Learning Rate: 0.0000308
# Epoch [321/400], Loss: 13.20476,  Test Loss: 27.08730, Test Loss Distribution Params: 6.69934,Learning Rate: 0.0000305
# Epoch [322/400], Loss: 10.05238,  Test Loss: 25.23642, Test Loss Distribution Params: 5.85687,Learning Rate: 0.0000303
# Epoch [323/400], Loss: 9.80620,  Test Loss: 24.81617, Test Loss Distribution Params: 5.70572,Learning Rate: 0.0000300
# Epoch [324/400], Loss: 11.17954,  Test Loss: 25.14220, Test Loss Distribution Params: 5.97430,Learning Rate: 0.0000298
# Epoch [325/400], Loss: 11.33552,  Test Loss: 26.32603, Test Loss Distribution Params: 6.68403,Learning Rate: 0.0000296
# Epoch [326/400], Loss: 11.65253,  Test Loss: 27.53970, Test Loss Distribution Params: 7.26589,Learning Rate: 0.0000293
# Epoch [327/400], Loss: 10.06250,  Test Loss: 27.67674, Test Loss Distribution Params: 7.21534,Learning Rate: 0.0000291
# Epoch [328/400], Loss: 16.09912,  Test Loss: 28.79989, Test Loss Distribution Params: 7.74317,Learning Rate: 0.0000289
# Epoch [329/400], Loss: 9.55843,  Test Loss: 30.32765, Test Loss Distribution Params: 8.40123,Learning Rate: 0.0000286
# Epoch [330/400], Loss: 12.08557,  Test Loss: 30.61216, Test Loss Distribution Params: 8.45315,Learning Rate: 0.0000284
# Epoch [331/400], Loss: 9.25593,  Test Loss: 30.93752, Test Loss Distribution Params: 8.66861,Learning Rate: 0.0000282
# Epoch [332/400], Loss: 10.28642,  Test Loss: 31.73714, Test Loss Distribution Params: 9.13784,Learning Rate: 0.0000279
# Epoch [333/400], Loss: 10.26399,  Test Loss: 31.84389, Test Loss Distribution Params: 9.27326,Learning Rate: 0.0000277
# Epoch [334/400], Loss: 12.56780,  Test Loss: 31.43622, Test Loss Distribution Params: 9.13590,Learning Rate: 0.0000275
# Epoch [335/400], Loss: 9.22127,  Test Loss: 29.89270, Test Loss Distribution Params: 8.30266,Learning Rate: 0.0000273
# Epoch [336/400], Loss: 12.25797,  Test Loss: 27.54816, Test Loss Distribution Params: 6.96688,Learning Rate: 0.0000271
# Epoch [337/400], Loss: 12.27453,  Test Loss: 26.07236, Test Loss Distribution Params: 6.15112,Learning Rate: 0.0000268
# Epoch [338/400], Loss: 14.70297,  Test Loss: 25.58902, Test Loss Distribution Params: 5.90632,Learning Rate: 0.0000266
# Epoch [339/400], Loss: 10.24063,  Test Loss: 24.76746, Test Loss Distribution Params: 5.46855,Learning Rate: 0.0000264
# Epoch [340/400], Loss: 18.96433,  Test Loss: 24.56002, Test Loss Distribution Params: 5.39074,Learning Rate: 0.0000262
# Epoch [341/400], Loss: 9.84941,  Test Loss: 24.27343, Test Loss Distribution Params: 5.22963,Learning Rate: 0.0000260
# Epoch [342/400], Loss: 9.68830,  Test Loss: 24.14879, Test Loss Distribution Params: 5.12485,Learning Rate: 0.0000258
# Epoch [343/400], Loss: 10.62773,  Test Loss: 24.18712, Test Loss Distribution Params: 5.06680,Learning Rate: 0.0000256
# Epoch [344/400], Loss: 12.09040,  Test Loss: 23.97413, Test Loss Distribution Params: 4.96103,Learning Rate: 0.0000254
# Epoch [345/400], Loss: 10.26365,  Test Loss: 23.60362, Test Loss Distribution Params: 4.70605,Learning Rate: 0.0000252
# Epoch [346/400], Loss: 11.23349,  Test Loss: 23.25329, Test Loss Distribution Params: 4.56145,Learning Rate: 0.0000250
# Epoch [347/400], Loss: 10.32543,  Test Loss: 23.87006, Test Loss Distribution Params: 4.87037,Learning Rate: 0.0000248
# Epoch [348/400], Loss: 11.21177,  Test Loss: 24.41545, Test Loss Distribution Params: 5.17513,Learning Rate: 0.0000246
# Epoch [349/400], Loss: 9.69312,  Test Loss: 24.53971, Test Loss Distribution Params: 5.26299,Learning Rate: 0.0000244
# Epoch [350/400], Loss: 9.83439,  Test Loss: 24.72449, Test Loss Distribution Params: 5.35388,Learning Rate: 0.0000242
# Epoch [351/400], Loss: 11.41036,  Test Loss: 24.89977, Test Loss Distribution Params: 5.47102,Learning Rate: 0.0000240
# Epoch [352/400], Loss: 10.37978,  Test Loss: 24.70398, Test Loss Distribution Params: 5.38704,Learning Rate: 0.0000238
# Epoch [353/400], Loss: 9.78779,  Test Loss: 24.74892, Test Loss Distribution Params: 5.46314,Learning Rate: 0.0000236
# Epoch [354/400], Loss: 9.03209,  Test Loss: 24.63114, Test Loss Distribution Params: 5.42961,Learning Rate: 0.0000234
# Epoch [355/400], Loss: 9.21515,  Test Loss: 24.51051, Test Loss Distribution Params: 5.36698,Learning Rate: 0.0000232
# Epoch [356/400], Loss: 12.35002,  Test Loss: 24.21875, Test Loss Distribution Params: 5.12739,Learning Rate: 0.0000231
# Epoch [357/400], Loss: 15.08705,  Test Loss: 24.68802, Test Loss Distribution Params: 5.32000,Learning Rate: 0.0000229
# Epoch [358/400], Loss: 13.65932,  Test Loss: 24.86186, Test Loss Distribution Params: 5.41264,Learning Rate: 0.0000227
# Epoch [359/400], Loss: 9.19552,  Test Loss: 25.31094, Test Loss Distribution Params: 5.67492,Learning Rate: 0.0000225
# Epoch [360/400], Loss: 11.79823,  Test Loss: 25.34964, Test Loss Distribution Params: 5.73446,Learning Rate: 0.0000223
# Epoch [361/400], Loss: 9.68690,  Test Loss: 24.76471, Test Loss Distribution Params: 5.38929,Learning Rate: 0.0000221
# Epoch [362/400], Loss: 9.94704,  Test Loss: 24.54614, Test Loss Distribution Params: 5.19834,Learning Rate: 0.0000220
# Epoch [363/400], Loss: 9.88828,  Test Loss: 24.40831, Test Loss Distribution Params: 5.10803,Learning Rate: 0.0000218
# Epoch [364/400], Loss: 10.83790,  Test Loss: 23.82313, Test Loss Distribution Params: 4.72230,Learning Rate: 0.0000216
# Epoch [365/400], Loss: 9.38150,  Test Loss: 23.50274, Test Loss Distribution Params: 4.60131,Learning Rate: 0.0000214
# Epoch [366/400], Loss: 13.43035,  Test Loss: 23.37502, Test Loss Distribution Params: 4.64960,Learning Rate: 0.0000213
# Epoch [367/400], Loss: 9.59125,  Test Loss: 23.49477, Test Loss Distribution Params: 4.74982,Learning Rate: 0.0000211
# Epoch [368/400], Loss: 9.22735,  Test Loss: 23.51854, Test Loss Distribution Params: 4.75548,Learning Rate: 0.0000209
# Epoch [369/400], Loss: 12.65860,  Test Loss: 23.51742, Test Loss Distribution Params: 4.78397,Learning Rate: 0.0000208
# Epoch [370/400], Loss: 12.64978,  Test Loss: 23.60791, Test Loss Distribution Params: 4.75584,Learning Rate: 0.0000206
# Epoch [371/400], Loss: 14.10567,  Test Loss: 23.90254, Test Loss Distribution Params: 4.89502,Learning Rate: 0.0000204
# Epoch [372/400], Loss: 9.80006,  Test Loss: 24.03472, Test Loss Distribution Params: 5.01137,Learning Rate: 0.0000203
# Epoch [373/400], Loss: 10.41538,  Test Loss: 24.08882, Test Loss Distribution Params: 5.06088,Learning Rate: 0.0000201
# Epoch [374/400], Loss: 10.22027,  Test Loss: 23.94260, Test Loss Distribution Params: 5.00939,Learning Rate: 0.0000200
# Epoch [375/400], Loss: 13.36713,  Test Loss: 24.54580, Test Loss Distribution Params: 5.38348,Learning Rate: 0.0000198
# Epoch [376/400], Loss: 11.00712,  Test Loss: 24.61996, Test Loss Distribution Params: 5.47733,Learning Rate: 0.0000196
# Epoch [377/400], Loss: 9.62992,  Test Loss: 24.74865, Test Loss Distribution Params: 5.55999,Learning Rate: 0.0000195
# Epoch [378/400], Loss: 9.02754,  Test Loss: 24.57848, Test Loss Distribution Params: 5.47914,Learning Rate: 0.0000193
# Epoch [379/400], Loss: 10.18356,  Test Loss: 24.69509, Test Loss Distribution Params: 5.50555,Learning Rate: 0.0000192
# Epoch [380/400], Loss: 8.99428,  Test Loss: 25.48046, Test Loss Distribution Params: 5.94078,Learning Rate: 0.0000190
# Epoch [381/400], Loss: 10.63263,  Test Loss: 25.39142, Test Loss Distribution Params: 5.88415,Learning Rate: 0.0000189
# Epoch [382/400], Loss: 10.35816,  Test Loss: 26.37753, Test Loss Distribution Params: 6.45338,Learning Rate: 0.0000187
# Epoch [383/400], Loss: 18.14022,  Test Loss: 27.13956, Test Loss Distribution Params: 6.94829,Learning Rate: 0.0000186
# Epoch [384/400], Loss: 9.25175,  Test Loss: 26.34667, Test Loss Distribution Params: 6.46998,Learning Rate: 0.0000184
# Epoch [385/400], Loss: 8.76723,  Test Loss: 25.52638, Test Loss Distribution Params: 5.98222,Learning Rate: 0.0000183
# Epoch [386/400], Loss: 8.69534,  Test Loss: 25.22849, Test Loss Distribution Params: 5.76598,Learning Rate: 0.0000181
# Epoch [387/400], Loss: 26.94339,  Test Loss: 25.13829, Test Loss Distribution Params: 5.73273,Learning Rate: 0.0000180
# Epoch [388/400], Loss: 15.95108,  Test Loss: 25.62249, Test Loss Distribution Params: 6.02972,Learning Rate: 0.0000178
# Epoch [389/400], Loss: 8.89307,  Test Loss: 25.48060, Test Loss Distribution Params: 5.92360,Learning Rate: 0.0000177
# Epoch [390/400], Loss: 11.67480,  Test Loss: 24.72687, Test Loss Distribution Params: 5.46879,Learning Rate: 0.0000176
# Epoch [391/400], Loss: 9.60242,  Test Loss: 24.02891, Test Loss Distribution Params: 5.04644,Learning Rate: 0.0000174
# Epoch [392/400], Loss: 12.07190,  Test Loss: 23.76870, Test Loss Distribution Params: 4.90323,Learning Rate: 0.0000173
# Epoch [393/400], Loss: 13.17539,  Test Loss: 23.46438, Test Loss Distribution Params: 4.75483,Learning Rate: 0.0000171
# Epoch [394/400], Loss: 9.87954,  Test Loss: 23.57007, Test Loss Distribution Params: 4.85195,Learning Rate: 0.0000170
# Epoch [395/400], Loss: 9.32963,  Test Loss: 23.69298, Test Loss Distribution Params: 4.92469,Learning Rate: 0.0000169
# Epoch [396/400], Loss: 12.80607,  Test Loss: 23.80279, Test Loss Distribution Params: 5.05615,Learning Rate: 0.0000167
# Epoch [397/400], Loss: 9.12203,  Test Loss: 24.09488, Test Loss Distribution Params: 5.23406,Learning Rate: 0.0000166
# Epoch [398/400], Loss: 10.47415,  Test Loss: 24.01683, Test Loss Distribution Params: 5.26249,Learning Rate: 0.0000165
# Epoch [399/400], Loss: 10.83208,  Test Loss: 23.52368, Test Loss Distribution Params: 4.96267,Learning Rate: 0.0000163
# Epoch [400/400], Loss: 8.66388,  Test Loss: 23.59573, Test Loss Distribution Params: 4.96617,Learning Rate: 0.0000162
# Training finished!

# %%
out2.shape
# Out:
# torch.Size([10, 1])

# %%
a,b=next(iter(dataloader))
a.shape
# Out:
# torch.Size([8, 40, 1000, 1000])

# %%
plt.imshow(a[6,30,:,:])

# %%
scales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 scales
#
# NameError: name 'scales' is not defined

# %%
criterion(outputs_tst, speed_tst.to(device))
# Out:
# tensor(2.9196, device='cuda:0')

# %%
outputs_tst
# Out:
# tensor([[-3.6606e-04, -1.1973e-03,  4.5290e-03,  ...,  2.3624e-01,
#           2.4830e-01,  3.2491e-01],
#         [ 1.1595e-04,  5.3141e-04,  3.8370e-03,  ...,  3.3265e-01,
#           3.6238e-01,  4.5133e-01],
#         [-3.1799e-04, -1.0315e-03,  4.4717e-03,  ...,  2.4626e-01,
#           2.6008e-01,  3.3805e-01],
#         [-6.0153e-05, -1.3037e-04,  4.1123e-03,  ...,  2.9629e-01,
#           3.1932e-01,  4.0370e-01]], device='cuda:0')

# %%
k=1
out = outputs_tst[k,:].cpu().detach().squeeze()
#

def rolling_mean(matrix, window):
    df = pd.DataFrame(matrix)
    return df.rolling(window=window).mean().dropna().to_numpy()
out_mean = rolling_mean(out,6)
out_mean[out_mean<0]=0.001
    # for i in out:
#     if (i>.03)&(count<400):
#         out[:,count
#     count+=1
plt.plot(out_mean)
plt.plot(speed_tst[k])

# %%
a,b = expon.fit(out_mean)
#c=c+.4
#a=a+.1
# Generate points for plotting the fitted distribution
xtorch= np.linspace(expon.ppf(0.01, a,b),
                expon.ppf(0.99, a,b), target_length)

distr_torch=expon.pdf(xtorch, a,b)
print(a+b)
print(a,b)
# scales[i,:] = torch.tensor([a,b,c])
plt.plot(xtorch,distr_torch,c='r')

a = (3*a_tst[k].cpu().detach().numpy()+a)/4
b = (3*b_tst[k].cpu().detach().numpy()+b)/4
print(a+b)
print(a,b)
xtorch= np.linspace(expon.ppf(0.01, a,b),
                expon.ppf(0.99, a,b), target_length)

distr_torch=expon.pdf(xtorch, a,b)
print(a,b)
# scales[i,:] = torch.tensor([a,b,c])
plt.plot(xtorch,distr_torch,c='b')

a,b = expon.fit(speed_tst[k])
    
# Generate points for plotting the fitted distribution
xtorch= np.linspace(expon.ppf(0.01, a,b),
                expon.ppf(0.99, a,b), target_length)

distr_torch=expon.pdf(xtorch, a,b)
print(a+b)
print(a,b)

# scales[i,:] = torch.tensor([a,b,c])
plt.plot(xtorch,distr_torch,c='g')
# Out:
# 42.74388079466339
# 0.001 42.74288079466339
# [42.8766]
# [0.0734987] [42.8031]
# [0.0734987] [42.8031]
# 44.414356674999
# 0.03902479633688927 44.37533187866211

# %%
torch.save(model.state_dict(), 'turn_angle_model')

# %%
(b_tst[k].cpu().detach().numpy()+b)/2
# Out:
# array([-0.16220948], dtype=float32)

# %%
(c_tst[k].cpu().detach().numpy()+c)/2
# Out:
# array([2.6426258], dtype=float32)

# %%
# [ 1.2188,  0.0247, 11.8741]
# [1.2127, 0.0080, 6.0299]
# [1.2127, 0.0316, 6.0299]
s1 = scale_tst[:,0]#*1.2127
s2 = scale_tst[:,1]#*0.0316
s3 = scale_tst[:,2]#*6.0299

out1 = outputs_tst.cpu().detach().numpy()[:,0]#*1.2127
out2 = outputs_tst.cpu().detach().numpy()[:,1]#*0.0316
out3 = outputs_tst.cpu().detach().numpy()[:,2]#*6.0299

# %%
k=0
x_shape= torch.tensor(np.linspace(lognorm.ppf(0.01, out1[k], out2[k], out3[k]),
                    lognorm.ppf(0.99,  out1[k], out2[k], out3[k]), 100))

x_distr=torch.tensor(lognorm.pdf(x_shape,  out1[k], out2[k], out3[k]))

# %%
x_shape_or= torch.tensor(np.linspace(lognorm.ppf(0.01, s1[k], s2[k], s3[k]),
                    lognorm.ppf(0.99,  s1[k], s2[k], s3[k]), 100))

x_distr_or=torch.tensor(lognorm.pdf(x_shape,  s1[k], s2[k], s3[k]))

# %%
plt.scatter(x_shape,x_distr)
plt.scatter(x_shape_or,x_distr_or)

# %%
plt.scatter(xt.cpu().detach().numpy(),lab.cpu().detach().numpy())
plt.scatter(outputs[0].cpu().detach().numpy(),outputs[1].cpu().detach().numpy())

# %%
torch.save(model.state_dict(), 'weights_3_9_2')

# %%
dataset_test = CustomDataset(images3, coords_test)
test_dataloader = DataLoader(dataset_test, batch_size=batch_size, shuffle=False, drop_last=True)
model.eval()
running_loss2=0
with torch.no_grad():
    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        #labels= labels.to(device)
        #lab = torch.mean(lab, dim=(2,3)).squeeze()

        outp = model(inputs)  
        test_loss = criterion(outp, labels.to(device))
        running_loss2 += test_loss.item()
epoch_loss2 = running_loss2 / len(test_dataloader)
epoch_loss2
# Out:
# 340231.74375

# %%
# next(iter(dataloader))
ina.shape

# %%
outp

# %%
for i in range(672):
    print(torch.nan_to_num(xc_data[0:14,i]))

# %%
np_out = np.array(outp.cpu().detach())
np_out[np_out<=20]=np.nan
np_out.shape
# Out:
# (10, 2000, 2)

# %%
np_lab = np.array(labels.detach())
np_lab[np_lab==0]=np.nan

# %%
np_lab
# Out:
# array([[[360.78415, 335.69382],
#         [      nan,       nan],
#         [      nan,       nan],
#         ...,
#         [      nan,       nan],
#         [      nan,       nan],
#         [      nan,       nan]],
#
#        [[377.5993 , 342.52182],
#         [      nan,       nan],
#         [      nan,       nan],
#         ...,
#         [      nan,       nan],
#         [      nan,       nan],
#         [      nan,       nan]],
#
#        [[395.49115, 347.76654],
#         [      nan,       nan],
#         [      nan,       nan],
#         ...,
#         [      nan,       nan],
#         [      nan,       nan],
#         [      nan,       nan]],
#
#        [[415.54092, 350.15506],
#         [      nan,       nan],
#         [      nan,       nan],
#         ...,
#         [      nan,       nan],
#         [      nan,       nan],
#         [      nan,       nan]]], dtype=float32)

# %%
for i in range(np_out.shape[0]):
    plt.scatter(np_out[i,:,0],np_out[i,:,1])

# %%
for i in range(np_lab.shape[0]):
    plt.scatter(np_lab[i,:,0],np_lab[i,:,1])

# %%
for i in range(np_lab.shape[1]):
    plt.plot(np_lab[:,i,0],np_lab[:,i,1])

# %%
for i in range(np_out.shape[1]):
    plt.plot(np_out[:,i,0],np_out[:,i,1])

# %%
plt.plot(np_lab[:,i,0],np_lab[:,i,1])
plt.plot(np_out[:,i,0],np_out[:,i,1])

# %%
np_out[:,i,0]

# %%
np_out[:,i,1]

# %%
lab[:,0,0]
